# %% [markdown]
# # Activity 1.2 : Training Neural Networks

# %% [markdown]
# #### Objective(s):
#
# This activity aims to demonstrate how to train neural networks using keras

# %% [markdown]
# #### Intended Learning Outcomes (ILOs):
# * Demonstrate how to build and train neural networks
# * Demonstrate how to evaluate and plot the model using training and validation loss

# %% [markdown]
# #### Resources:
# * Jupyter Notebook
#
# CI Pima Diabetes Dataset
#
# * pima-indians-diabetes.csv

# %% [markdown]
# #### Procedures

# %% [markdown]
# Load the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, precision_recall_curve, roc_auc_score, roc_curve, accuracy_score
from sklearn.ensemble import RandomForestClassifier

import seaborn as sns

# %matplotlib inline

# %%
## Import Keras objects for Deep Learning

from keras.models  import Sequential
from keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization
from keras.optimizers import Adam, SGD, RMSprop
# Out:
# C:\Users\LeonPascual\miniconda3\envs\CPE312_Pascual\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %% [markdown]
# Load the dataset

# %%
filepath = "pima-indians-diabetes.csv"
names = ["times_pregnant", "glucose_tolerance_test", "blood_pressure", "skin_thickness", "insulin", 
         "bmi", "pedigree_function", "age", "has_diabetes"]
diabetes_df = pd.read_csv(filepath, names=names)

# %% [markdown]
# Check the top 5 samples of the data

# %%
print(diabetes_df.shape)
diabetes_df.sample(5)
# Out:
# (768, 9)
#      times_pregnant  glucose_tolerance_test  blood_pressure  skin_thickness  \
# 182               1                       0              74              20
# 631               0                     102              78              40
# 674               8                      91              82               0
# 20                3                     126              88              41
# 226               0                     101              76               0
#
#      insulin   bmi  pedigree_function  age  has_diabetes
# 182       23  27.7              0.299   21             0
# 631       90  34.5              0.238   24             0
# 674        0  35.6              0.587   68             0
# 20       235  39.3              0.704   27             0
# 226        0  35.7              0.198   26             0

# %%
diabetes_df.dtypes
# Out:
# times_pregnant              int64
# glucose_tolerance_test      int64
# blood_pressure              int64
# skin_thickness              int64
# insulin                     int64
# bmi                       float64
# pedigree_function         float64
# age                         int64
# has_diabetes                int64
# dtype: object

# %%
X = diabetes_df.iloc[:, :-1].values
y = diabetes_df["has_diabetes"].values

# %% [markdown]
# Split the data to Train, and Test (75%, 25%)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=11111)

# %%
np.mean(y), np.mean(1-y)
# Out:
# (np.float64(0.3489583333333333), np.float64(0.6510416666666666))

# %% [markdown]
# Build a single hidden layer neural network using 12 nodes.
# Use the sequential model with single layer network and input shape to 8.

# %% [markdown]
# Normalize the data

# %%
normalizer = StandardScaler()
X_train_norm = normalizer.fit_transform(X_train)
X_test_norm = normalizer.transform(X_test)

# %% [markdown]
# Define the model:
# * Input size is 8-dimensional
# * 1 hidden layer, 12 hidden nodes, sigmoid activation
# * Final layer with one node and sigmoid activation (standard for binary classification)

# %%
model  = Sequential([
    Dense(12, input_shape=(8,), activation="relu"),
    Dense(1, activation="sigmoid")
])
# Out:
# C:\Users\LeonPascual\miniconda3\envs\CPE312_Pascual\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# View the model summary

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 12)                  │             108 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              13 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 121 (484.00 B)
#  Trainable params: 121 (484.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Train the model
# * Compile the model with optimizer, loss function and metrics
# * Use the fit function to return the run history.

# %%
model.compile(SGD(learning_rate =.003), "binary_crossentropy", metrics=["accuracy"])
run_hist_1 = model.fit(X_train_norm, y_train, validation_data=(X_test_norm, y_test), epochs=200)
# Out:
# Epoch 1/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4340 - loss: 0.8875 - val_accuracy: 0.4688 - val_loss: 0.8278
# Epoch 2/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4583 - loss: 0.8614 - val_accuracy: 0.4844 - val_loss: 0.8052
# Epoch 3/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4826 - loss: 0.8374 - val_accuracy: 0.4896 - val_loss: 0.7845
# Epoch 4/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4948 - loss: 0.8155 - val_accuracy: 0.4948 - val_loss: 0.7656
# Epoch 5/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5122 - loss: 0.7954 - val_accuracy: 0.5104 - val_loss: 0.7482
# Epoch 6/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5330 - loss: 0.7768 - val_accuracy: 0.5260 - val_loss: 0.7323
# Epoch 7/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5486 - loss: 0.7598 - val_accuracy: 0.5417 - val_loss: 0.7177
# Epoch 8/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5573 - loss: 0.7442 - val_accuracy: 0.5365 - val_loss: 0.7043
# Epoch 9/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5660 - loss: 0.7298 - val_accuracy: 0.5521 - val_loss: 0.6920
# Epoch 10/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5764 - loss: 0.7165 - val_accuracy: 0.5625 - val_loss: 0.6807
# Epoch 11/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5885 - loss: 0.7043 - val_accuracy: 0.5729 - val_loss: 0.6704
# Epoch 12/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5972 - loss: 0.6930 - val_accuracy: 0.5938 - val_loss: 0.6608
# Epoch 13/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5990 - loss: 0.6825 - val_accuracy: 0.5938 - val_loss: 0.6520
# Epoch 14/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6094 - loss: 0.6729 - val_accuracy: 0.5990 - val_loss: 0.6439
# Epoch 15/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6181 - loss: 0.6639 - val_accuracy: 0.6146 - val_loss: 0.6365
# Epoch 16/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6337 - loss: 0.6556 - val_accuracy: 0.6198 - val_loss: 0.6296
# Epoch 17/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6406 - loss: 0.6480 - val_accuracy: 0.6406 - val_loss: 0.6232
# Epoch 18/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6528 - loss: 0.6408 - val_accuracy: 0.6719 - val_loss: 0.6173
# Epoch 19/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6458 - loss: 0.6341 - val_accuracy: 0.6667 - val_loss: 0.6118
# Epoch 20/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6562 - loss: 0.6279 - val_accuracy: 0.6562 - val_loss: 0.6068
# Epoch 21/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6597 - loss: 0.6222 - val_accuracy: 0.6667 - val_loss: 0.6021
# Epoch 22/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6649 - loss: 0.6167 - val_accuracy: 0.6771 - val_loss: 0.5977
# Epoch 23/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6719 - loss: 0.6117 - val_accuracy: 0.6771 - val_loss: 0.5937
# Epoch 24/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6858 - loss: 0.6070 - val_accuracy: 0.6875 - val_loss: 0.5899
# Epoch 25/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6875 - loss: 0.6025 - val_accuracy: 0.6823 - val_loss: 0.5864
# Epoch 26/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6892 - loss: 0.5983 - val_accuracy: 0.6875 - val_loss: 0.5831
# Epoch 27/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6927 - loss: 0.5943 - val_accuracy: 0.6875 - val_loss: 0.5800
# Epoch 28/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6979 - loss: 0.5906 - val_accuracy: 0.6979 - val_loss: 0.5771
# Epoch 29/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.6979 - loss: 0.5872 - val_accuracy: 0.6979 - val_loss: 0.5745
# Epoch 30/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6944 - loss: 0.5839 - val_accuracy: 0.7031 - val_loss: 0.5719
# Epoch 31/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6962 - loss: 0.5807 - val_accuracy: 0.7135 - val_loss: 0.5696
# Epoch 32/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6979 - loss: 0.5778 - val_accuracy: 0.7240 - val_loss: 0.5673
# Epoch 33/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6979 - loss: 0.5749 - val_accuracy: 0.7292 - val_loss: 0.5652
# Epoch 34/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6979 - loss: 0.5723 - val_accuracy: 0.7240 - val_loss: 0.5633
# Epoch 35/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6962 - loss: 0.5697 - val_accuracy: 0.7292 - val_loss: 0.5614
# Epoch 36/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6997 - loss: 0.5673 - val_accuracy: 0.7188 - val_loss: 0.5596
# Epoch 37/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7014 - loss: 0.5650 - val_accuracy: 0.7188 - val_loss: 0.5580
# Epoch 38/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7031 - loss: 0.5628 - val_accuracy: 0.7188 - val_loss: 0.5564
# Epoch 39/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7049 - loss: 0.5607 - val_accuracy: 0.7188 - val_loss: 0.5549
# Epoch 40/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7101 - loss: 0.5588 - val_accuracy: 0.7240 - val_loss: 0.5535
# Epoch 41/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7153 - loss: 0.5569 - val_accuracy: 0.7188 - val_loss: 0.5522
# Epoch 42/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7170 - loss: 0.5550 - val_accuracy: 0.7240 - val_loss: 0.5509
# Epoch 43/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7135 - loss: 0.5533 - val_accuracy: 0.7292 - val_loss: 0.5496
# Epoch 44/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7153 - loss: 0.5516 - val_accuracy: 0.7292 - val_loss: 0.5485
# Epoch 45/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7170 - loss: 0.5500 - val_accuracy: 0.7344 - val_loss: 0.5473
# Epoch 46/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7188 - loss: 0.5484 - val_accuracy: 0.7344 - val_loss: 0.5463
# Epoch 47/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7188 - loss: 0.5469 - val_accuracy: 0.7344 - val_loss: 0.5452
# Epoch 48/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7222 - loss: 0.5455 - val_accuracy: 0.7344 - val_loss: 0.5443
# Epoch 49/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7240 - loss: 0.5441 - val_accuracy: 0.7344 - val_loss: 0.5433
# Epoch 50/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7292 - loss: 0.5427 - val_accuracy: 0.7344 - val_loss: 0.5424
# Epoch 51/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7309 - loss: 0.5414 - val_accuracy: 0.7344 - val_loss: 0.5415
# Epoch 52/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7396 - loss: 0.5402 - val_accuracy: 0.7344 - val_loss: 0.5406
# Epoch 53/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7361 - loss: 0.5389 - val_accuracy: 0.7344 - val_loss: 0.5398
# Epoch 54/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7396 - loss: 0.5377 - val_accuracy: 0.7344 - val_loss: 0.5390
# Epoch 55/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7413 - loss: 0.5366 - val_accuracy: 0.7344 - val_loss: 0.5382
# Epoch 56/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7378 - loss: 0.5355 - val_accuracy: 0.7344 - val_loss: 0.5375
# Epoch 57/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7396 - loss: 0.5343 - val_accuracy: 0.7292 - val_loss: 0.5367
# Epoch 58/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7413 - loss: 0.5333 - val_accuracy: 0.7292 - val_loss: 0.5360
# Epoch 59/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7448 - loss: 0.5322 - val_accuracy: 0.7292 - val_loss: 0.5353
# Epoch 60/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7448 - loss: 0.5312 - val_accuracy: 0.7292 - val_loss: 0.5347
# Epoch 61/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7465 - loss: 0.5302 - val_accuracy: 0.7292 - val_loss: 0.5340
# Epoch 62/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7431 - loss: 0.5293 - val_accuracy: 0.7292 - val_loss: 0.5334
# Epoch 63/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7431 - loss: 0.5283 - val_accuracy: 0.7344 - val_loss: 0.5327
# Epoch 64/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7431 - loss: 0.5274 - val_accuracy: 0.7396 - val_loss: 0.5321
# Epoch 65/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7431 - loss: 0.5265 - val_accuracy: 0.7396 - val_loss: 0.5315
# Epoch 66/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7396 - loss: 0.5256 - val_accuracy: 0.7448 - val_loss: 0.5309
# Epoch 67/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7431 - loss: 0.5247 - val_accuracy: 0.7448 - val_loss: 0.5304
# Epoch 68/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7431 - loss: 0.5239 - val_accuracy: 0.7500 - val_loss: 0.5298
# Epoch 69/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7448 - loss: 0.5230 - val_accuracy: 0.7604 - val_loss: 0.5292
# Epoch 70/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7448 - loss: 0.5222 - val_accuracy: 0.7656 - val_loss: 0.5287
# Epoch 71/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7448 - loss: 0.5214 - val_accuracy: 0.7604 - val_loss: 0.5282
# Epoch 72/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7465 - loss: 0.5206 - val_accuracy: 0.7604 - val_loss: 0.5276
# Epoch 73/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7465 - loss: 0.5199 - val_accuracy: 0.7604 - val_loss: 0.5271
# Epoch 74/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7448 - loss: 0.5191 - val_accuracy: 0.7656 - val_loss: 0.5266
# Epoch 75/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7431 - loss: 0.5183 - val_accuracy: 0.7656 - val_loss: 0.5261
# Epoch 76/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7448 - loss: 0.5176 - val_accuracy: 0.7656 - val_loss: 0.5256
# Epoch 77/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7431 - loss: 0.5169 - val_accuracy: 0.7656 - val_loss: 0.5251
# Epoch 78/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7413 - loss: 0.5162 - val_accuracy: 0.7604 - val_loss: 0.5246
# Epoch 79/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7413 - loss: 0.5155 - val_accuracy: 0.7604 - val_loss: 0.5242
# Epoch 80/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7413 - loss: 0.5148 - val_accuracy: 0.7604 - val_loss: 0.5237
# Epoch 81/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7413 - loss: 0.5141 - val_accuracy: 0.7604 - val_loss: 0.5232
# Epoch 82/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7396 - loss: 0.5134 - val_accuracy: 0.7604 - val_loss: 0.5228
# Epoch 83/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7378 - loss: 0.5128 - val_accuracy: 0.7656 - val_loss: 0.5223
# Epoch 84/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7378 - loss: 0.5121 - val_accuracy: 0.7708 - val_loss: 0.5219
# Epoch 85/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7378 - loss: 0.5114 - val_accuracy: 0.7708 - val_loss: 0.5214
# Epoch 86/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7378 - loss: 0.5108 - val_accuracy: 0.7708 - val_loss: 0.5210
# Epoch 87/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7361 - loss: 0.5102 - val_accuracy: 0.7708 - val_loss: 0.5206
# Epoch 88/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7378 - loss: 0.5095 - val_accuracy: 0.7708 - val_loss: 0.5202
# Epoch 89/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7361 - loss: 0.5089 - val_accuracy: 0.7708 - val_loss: 0.5197
# Epoch 90/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7378 - loss: 0.5083 - val_accuracy: 0.7708 - val_loss: 0.5193
# Epoch 91/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7361 - loss: 0.5077 - val_accuracy: 0.7708 - val_loss: 0.5189
# Epoch 92/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7361 - loss: 0.5071 - val_accuracy: 0.7708 - val_loss: 0.5185
# Epoch 93/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7344 - loss: 0.5064 - val_accuracy: 0.7708 - val_loss: 0.5181
# Epoch 94/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7378 - loss: 0.5058 - val_accuracy: 0.7708 - val_loss: 0.5177
# Epoch 95/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7378 - loss: 0.5053 - val_accuracy: 0.7708 - val_loss: 0.5173
# Epoch 96/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7396 - loss: 0.5047 - val_accuracy: 0.7656 - val_loss: 0.5169
# Epoch 97/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7396 - loss: 0.5041 - val_accuracy: 0.7656 - val_loss: 0.5165
# Epoch 98/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7413 - loss: 0.5035 - val_accuracy: 0.7656 - val_loss: 0.5161
# Epoch 99/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7431 - loss: 0.5029 - val_accuracy: 0.7708 - val_loss: 0.5157
# Epoch 100/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7448 - loss: 0.5024 - val_accuracy: 0.7708 - val_loss: 0.5153
# Epoch 101/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7448 - loss: 0.5018 - val_accuracy: 0.7708 - val_loss: 0.5149
# Epoch 102/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7431 - loss: 0.5013 - val_accuracy: 0.7760 - val_loss: 0.5145
# Epoch 103/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7465 - loss: 0.5007 - val_accuracy: 0.7760 - val_loss: 0.5142
# Epoch 104/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7465 - loss: 0.5002 - val_accuracy: 0.7760 - val_loss: 0.5138
# Epoch 105/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7465 - loss: 0.4997 - val_accuracy: 0.7760 - val_loss: 0.5135
# Epoch 106/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7465 - loss: 0.4991 - val_accuracy: 0.7760 - val_loss: 0.5131
# Epoch 107/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7448 - loss: 0.4986 - val_accuracy: 0.7812 - val_loss: 0.5128
# Epoch 108/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7500 - loss: 0.4981 - val_accuracy: 0.7812 - val_loss: 0.5124
# Epoch 109/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7483 - loss: 0.4976 - val_accuracy: 0.7812 - val_loss: 0.5121
# Epoch 110/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7483 - loss: 0.4971 - val_accuracy: 0.7812 - val_loss: 0.5117
# Epoch 111/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7483 - loss: 0.4966 - val_accuracy: 0.7812 - val_loss: 0.5114
# Epoch 112/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7483 - loss: 0.4961 - val_accuracy: 0.7812 - val_loss: 0.5111
# Epoch 113/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7500 - loss: 0.4956 - val_accuracy: 0.7812 - val_loss: 0.5107
# Epoch 114/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7500 - loss: 0.4951 - val_accuracy: 0.7812 - val_loss: 0.5104
# Epoch 115/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7500 - loss: 0.4947 - val_accuracy: 0.7812 - val_loss: 0.5101
# Epoch 116/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7500 - loss: 0.4942 - val_accuracy: 0.7812 - val_loss: 0.5097
# Epoch 117/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7500 - loss: 0.4937 - val_accuracy: 0.7812 - val_loss: 0.5094
# Epoch 118/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7500 - loss: 0.4933 - val_accuracy: 0.7865 - val_loss: 0.5091
# Epoch 119/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7500 - loss: 0.4928 - val_accuracy: 0.7865 - val_loss: 0.5088
# Epoch 120/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7500 - loss: 0.4924 - val_accuracy: 0.7865 - val_loss: 0.5085
# Epoch 121/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7500 - loss: 0.4919 - val_accuracy: 0.7865 - val_loss: 0.5082
# Epoch 122/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7517 - loss: 0.4914 - val_accuracy: 0.7865 - val_loss: 0.5079
# Epoch 123/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7517 - loss: 0.4910 - val_accuracy: 0.7865 - val_loss: 0.5076
# Epoch 124/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7517 - loss: 0.4906 - val_accuracy: 0.7865 - val_loss: 0.5073
# Epoch 125/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7535 - loss: 0.4901 - val_accuracy: 0.7865 - val_loss: 0.5070
# Epoch 126/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7535 - loss: 0.4897 - val_accuracy: 0.7865 - val_loss: 0.5067
# Epoch 127/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7535 - loss: 0.4893 - val_accuracy: 0.7865 - val_loss: 0.5064
# Epoch 128/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7552 - loss: 0.4889 - val_accuracy: 0.7865 - val_loss: 0.5061
# Epoch 129/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7535 - loss: 0.4885 - val_accuracy: 0.7865 - val_loss: 0.5059
# Epoch 130/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7535 - loss: 0.4881 - val_accuracy: 0.7865 - val_loss: 0.5056
# Epoch 131/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7535 - loss: 0.4877 - val_accuracy: 0.7865 - val_loss: 0.5053
# Epoch 132/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7535 - loss: 0.4872 - val_accuracy: 0.7865 - val_loss: 0.5051
# Epoch 133/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7535 - loss: 0.4868 - val_accuracy: 0.7865 - val_loss: 0.5048
# Epoch 134/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7535 - loss: 0.4864 - val_accuracy: 0.7865 - val_loss: 0.5045
# Epoch 135/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7552 - loss: 0.4860 - val_accuracy: 0.7865 - val_loss: 0.5043
# Epoch 136/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7569 - loss: 0.4856 - val_accuracy: 0.7865 - val_loss: 0.5040
# Epoch 137/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7587 - loss: 0.4853 - val_accuracy: 0.7865 - val_loss: 0.5038
# Epoch 138/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7569 - loss: 0.4849 - val_accuracy: 0.7812 - val_loss: 0.5035
# Epoch 139/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7552 - loss: 0.4845 - val_accuracy: 0.7812 - val_loss: 0.5033
# Epoch 140/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7552 - loss: 0.4841 - val_accuracy: 0.7812 - val_loss: 0.5030
# Epoch 141/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7587 - loss: 0.4837 - val_accuracy: 0.7812 - val_loss: 0.5028
# Epoch 142/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7587 - loss: 0.4833 - val_accuracy: 0.7812 - val_loss: 0.5026
# Epoch 143/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7604 - loss: 0.4830 - val_accuracy: 0.7812 - val_loss: 0.5024
# Epoch 144/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7622 - loss: 0.4826 - val_accuracy: 0.7812 - val_loss: 0.5021
# Epoch 145/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7622 - loss: 0.4822 - val_accuracy: 0.7812 - val_loss: 0.5019
# Epoch 146/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7622 - loss: 0.4819 - val_accuracy: 0.7812 - val_loss: 0.5017
# Epoch 147/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7604 - loss: 0.4815 - val_accuracy: 0.7812 - val_loss: 0.5015
# Epoch 148/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7604 - loss: 0.4812 - val_accuracy: 0.7812 - val_loss: 0.5012
# Epoch 149/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7604 - loss: 0.4808 - val_accuracy: 0.7865 - val_loss: 0.5010
# Epoch 150/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7604 - loss: 0.4805 - val_accuracy: 0.7865 - val_loss: 0.5008
# Epoch 151/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7604 - loss: 0.4801 - val_accuracy: 0.7865 - val_loss: 0.5006
# Epoch 152/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7604 - loss: 0.4798 - val_accuracy: 0.7865 - val_loss: 0.5004
# Epoch 153/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7622 - loss: 0.4795 - val_accuracy: 0.7865 - val_loss: 0.5002
# Epoch 154/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7622 - loss: 0.4792 - val_accuracy: 0.7865 - val_loss: 0.5000
# Epoch 155/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7622 - loss: 0.4788 - val_accuracy: 0.7865 - val_loss: 0.4998
# Epoch 156/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7622 - loss: 0.4785 - val_accuracy: 0.7865 - val_loss: 0.4996
# Epoch 157/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7622 - loss: 0.4782 - val_accuracy: 0.7865 - val_loss: 0.4994
# Epoch 158/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7639 - loss: 0.4779 - val_accuracy: 0.7865 - val_loss: 0.4992
# Epoch 159/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7639 - loss: 0.4775 - val_accuracy: 0.7865 - val_loss: 0.4990
# Epoch 160/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7639 - loss: 0.4772 - val_accuracy: 0.7865 - val_loss: 0.4988
# Epoch 161/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7639 - loss: 0.4769 - val_accuracy: 0.7865 - val_loss: 0.4986
# Epoch 162/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7639 - loss: 0.4766 - val_accuracy: 0.7865 - val_loss: 0.4984
# Epoch 163/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7639 - loss: 0.4763 - val_accuracy: 0.7865 - val_loss: 0.4982
# Epoch 164/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7639 - loss: 0.4760 - val_accuracy: 0.7865 - val_loss: 0.4981
# Epoch 165/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7639 - loss: 0.4757 - val_accuracy: 0.7865 - val_loss: 0.4979
# Epoch 166/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7639 - loss: 0.4753 - val_accuracy: 0.7917 - val_loss: 0.4977
# Epoch 167/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7656 - loss: 0.4750 - val_accuracy: 0.7917 - val_loss: 0.4975
# Epoch 168/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7656 - loss: 0.4747 - val_accuracy: 0.7917 - val_loss: 0.4973
# Epoch 169/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7656 - loss: 0.4744 - val_accuracy: 0.7917 - val_loss: 0.4972
# Epoch 170/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7656 - loss: 0.4741 - val_accuracy: 0.7917 - val_loss: 0.4970
# Epoch 171/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7656 - loss: 0.4738 - val_accuracy: 0.7917 - val_loss: 0.4968
# Epoch 172/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7656 - loss: 0.4736 - val_accuracy: 0.7917 - val_loss: 0.4966
# Epoch 173/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7674 - loss: 0.4733 - val_accuracy: 0.7917 - val_loss: 0.4965
# Epoch 174/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7674 - loss: 0.4730 - val_accuracy: 0.7917 - val_loss: 0.4963
# Epoch 175/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7674 - loss: 0.4727 - val_accuracy: 0.7917 - val_loss: 0.4961
# Epoch 176/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7674 - loss: 0.4724 - val_accuracy: 0.7917 - val_loss: 0.4960
# Epoch 177/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7674 - loss: 0.4721 - val_accuracy: 0.7917 - val_loss: 0.4958
# Epoch 178/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7674 - loss: 0.4718 - val_accuracy: 0.7917 - val_loss: 0.4956
# Epoch 179/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7691 - loss: 0.4716 - val_accuracy: 0.7969 - val_loss: 0.4955
# Epoch 180/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7691 - loss: 0.4713 - val_accuracy: 0.7969 - val_loss: 0.4953
# Epoch 181/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7674 - loss: 0.4710 - val_accuracy: 0.7969 - val_loss: 0.4952
# Epoch 182/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7691 - loss: 0.4707 - val_accuracy: 0.7969 - val_loss: 0.4950
# Epoch 183/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7674 - loss: 0.4705 - val_accuracy: 0.7969 - val_loss: 0.4949
# Epoch 184/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7674 - loss: 0.4702 - val_accuracy: 0.7969 - val_loss: 0.4947
# Epoch 185/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7691 - loss: 0.4699 - val_accuracy: 0.7969 - val_loss: 0.4946
# Epoch 186/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7691 - loss: 0.4697 - val_accuracy: 0.7969 - val_loss: 0.4944
# Epoch 187/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7691 - loss: 0.4694 - val_accuracy: 0.7969 - val_loss: 0.4943
# Epoch 188/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7691 - loss: 0.4692 - val_accuracy: 0.7917 - val_loss: 0.4941
# Epoch 189/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7691 - loss: 0.4689 - val_accuracy: 0.7917 - val_loss: 0.4940
# Epoch 190/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7708 - loss: 0.4687 - val_accuracy: 0.7917 - val_loss: 0.4939
# Epoch 191/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7708 - loss: 0.4684 - val_accuracy: 0.7917 - val_loss: 0.4937
# Epoch 192/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7708 - loss: 0.4681 - val_accuracy: 0.7865 - val_loss: 0.4936
# Epoch 193/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7708 - loss: 0.4679 - val_accuracy: 0.7865 - val_loss: 0.4935
# Epoch 194/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7708 - loss: 0.4677 - val_accuracy: 0.7865 - val_loss: 0.4933
# Epoch 195/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7743 - loss: 0.4675 - val_accuracy: 0.7865 - val_loss: 0.4932
# Epoch 196/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7726 - loss: 0.4672 - val_accuracy: 0.7865 - val_loss: 0.4931
# Epoch 197/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7726 - loss: 0.4670 - val_accuracy: 0.7865 - val_loss: 0.4929
# Epoch 198/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7726 - loss: 0.4667 - val_accuracy: 0.7865 - val_loss: 0.4928
# Epoch 199/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7726 - loss: 0.4665 - val_accuracy: 0.7865 - val_loss: 0.4927
# Epoch 200/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7726 - loss: 0.4662 - val_accuracy: 0.7865 - val_loss: 0.4926

# %%
## Like we did for the Random Forest, we generate two kinds of predictions
#  One is a hard decision, the other is a probabilitistic score.

y_pred_prob = model.predict(X_test_norm)  # Shape: (n_samples, 1), values in [0,1]
y_pred_class = (y_pred_prob > 0.5).astype(int)  # Binary: 0 or 1 [web:21]
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step

# %%
# Let's check out the outputs to get a feel for how keras apis work.
y_pred_class_nn_1[:10]
# Out:
# array([[0.5993208 ],
#        [0.8447913 ],
#        [0.30370638],
#        [0.17771429],
#        [0.22383448],
#        [0.49790466],
#        [0.02425634],
#        [0.2858935 ],
#        [0.9277605 ],
#        [0.184226  ]], dtype=float32)

# %%
y_pred_prob_nn_1[:10]
# Out:
# array([[0.5993208 ],
#        [0.8447913 ],
#        [0.30370638],
#        [0.17771429],
#        [0.22383448],
#        [0.49790466],
#        [0.02425634],
#        [0.2858935 ],
#        [0.9277605 ],
#        [0.184226  ]], dtype=float32)

# %% [markdown]
# Create the plot_roc function

# %%
def plot_roc(y_test, y_pred, model_name):
    fpr, tpr, thr = roc_curve(y_test, y_pred)
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.plot(fpr, tpr, 'k-')
    ax.plot([0, 1], [0, 1], 'k--', linewidth=.5)  # roc curve for random model
    ax.grid(True)
    ax.set(title='ROC Curve for {} on PIMA diabetes problem'.format(model_name),
           xlim=[-0.01, 1.01], ylim=[-0.01, 1.01])

# %% [markdown]
# Evaluate the model performance and plot the ROC CURVE

# %%
print('accuracy is {:.3f}'.format(accuracy_score(y_test,y_pred_class_nn_1)))
print('roc-auc is {:.3f}'.format(roc_auc_score(y_test,y_pred_prob_nn_1)))

plot_roc(y_test, y_pred_prob_nn_1, 'NN')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 print('accuracy is {:.3f}'.format(accuracy_score(y_test,y_pred_class_nn_1)))
#       2 print('roc-auc is {:.3f}'.format(roc_auc_score(y_test,y_pred_prob_nn_1)))
#       4 plot_roc(y_test, y_pred_prob_nn_1, 'NN')
#
# File C:\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File C:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:213, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     147 """Accuracy classification score.
#     148
#     149 In multilabel classification, this function computes subset accuracy:
#    (...)
#     209 0.5
#     210 """
#     212 # Compute accuracy for each possible representation
# --> 213 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     214 check_consistent_length(y_true, y_pred, sample_weight)
#     215 if y_type.startswith("multilabel"):
#
# File C:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:94, in _check_targets(y_true, y_pred)
#      91     y_type = {"multiclass"}
#      93 if len(y_type) > 1:
# ---> 94     raise ValueError(
#      95         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      96             type_true, type_pred
#      97         )
#      98     )
#     100 # We can't have more than one value on y_type => The set is no more needed
#     101 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets

# %% [markdown]
#  Plot the training loss and the validation loss over the different epochs and see how it looks

# %%
run_hist_1.history.keys()

# %%
fig, ax = plt.subplots()
ax.plot(run_hist_1.history["loss"],'r', marker='.', label="Train Loss")
ax.plot(run_hist_1.history["val_loss"],'b', marker='.', label="Validation Loss")
ax.legend()

# %% [markdown]
# What is your interpretation about the result of the train and validation loss?

# %% [markdown]
# #type your answer here

# %% [markdown]
# #### Supplementary Activity

# %% [markdown]
# * Build a model with two hidden layers, each with 6 nodes
# * Use the "relu" activation function for the hidden layers, and "sigmoid" for the final layer
# * Use a learning rate of .003 and train for 1500 epochs
# * Graph the trajectory of the loss functions, accuracy on both train and test set
# * Plot the roc curve for the predictions
# * Use different learning rates, numbers of epochs, and network structures.
# * Plot the results of training and validation loss using different learning rates, number of epocgs and network structures
# * Interpret your result

# %% [markdown]
# #### Conclusion

# %% [markdown]
# #type your answer here
